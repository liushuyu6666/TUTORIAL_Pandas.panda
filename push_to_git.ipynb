# %%
# %cd /content/drive/My Drive/Colab Notebooks/tutorial_pandas
# Out:
# /content/drive/My Drive/Colab Notebooks/tutorial_pandas

# %%
# %ll
# Out:
# total 204
# -rw------- 1 root 100228 Jun 13 21:04 data.csv
# -rw------- 1 root    358 Jun 13 21:27 dim.csv
# -rw------- 1 root 106972 Jun 13 21:30 pandas_SQL.ipynb
# -rw------- 1 root    406 Jun 14 14:58 push_to_git.ipynb

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Colab Notebooks/tutorial_pandas/.git/
